# %%
# import libraries
import pandas as pd

# %%
## EDA

# %%
df = pd.read_csv("housing_in_london.csv")

# %%
df.head()
# Out:
#          date            area  average_price       code  no_of_houses  \
# 0  1995-01-01  city of london          91449  E09000001           NaN
# 1  1995-02-01  city of london          82203  E09000001           NaN
# 2  1995-03-01  city of london          79121  E09000001           NaN
# 3  1995-04-01  city of london          77101  E09000001           NaN
# 4  1995-05-01  city of london          84409  E09000001           NaN
#
#   recycling_pct  houses_sold  life_satisfaction  median_salary mean_salary  \
# 0           NaN         17.0                NaN            NaN         NaN
# 1           NaN          7.0                NaN            NaN         NaN
# 2           NaN         14.0                NaN            NaN         NaN
# 3           NaN          7.0                NaN            NaN         NaN
# 4           NaN         10.0                NaN            NaN         NaN
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1
# ...

# %%
df.isnull()
# Out:
#         date   area  average_price   code  no_of_houses  recycling_pct  \
# 0      False  False          False  False          True           True
# 1      False  False          False  False          True           True
# 2      False  False          False  False          True           True
# 3      False  False          False  False          True           True
# 4      False  False          False  False          True           True
# ...      ...    ...            ...    ...           ...            ...
# 13544  False  False          False  False          True           True
# 13545  False  False          False  False          True           True
# 13546  False  False          False  False          True           True
# 13547  False  False          False  False          True           True
# 13548  False  False          False  False          True           True
#
#        houses_sold  life_satisfaction  median_salary  mean_salary  \
# ...
